# %%
# load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import sklearn as sklearn
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %% [markdown]
# # Spatial

# %%
# Load Dataset, Apply PCA and Create PCs

# Create DataFrame
df = pd.read_csv('upwelling_spatial.csv')
df = df.drop(columns = ['date (string)'])
df = df.dropna()

# Normalise the DataFrame
df2 = df.drop(columns = ['upwelling3day','upwelling1day'], axis = 1)

df2_mean = df2.mean()
df2_stdev = df2.std()
df2_norm = (df2 - df2_mean) / df2_stdev

target = df['upwelling3day']

# %%
# Apply PCA
pca = PCA(n_components = 8)
df2_PC = pca.fit_transform(df2_norm)

# Number of Upwelling Events and No Upwelling Events
upwelling = df['upwelling3day']
Upwelling1 = np.sum(upwelling == 1)
Upwelling0 = np.sum(upwelling == 0)

print('There are', Upwelling1, 'instances of Upwelling')
print('There are', Upwelling0, 'instances of No Upwelling')
# Out:
# There are 11513 instances of Upwelling
# There are 126359 instances of No Upwelling

# %%
# Create Training and Test Sets  
data_train, data_test, target_train, target_test = train_test_split(df2_PC, target, test_size = 0.20, random_state = 0, shuffle = True)

# %%
#4 Performing a Logistic Regression on a Training Set
log_reg = LogisticRegression()
log_reg.fit(data_train, target_train)
# Out:
# LogisticRegression()

# %%
# Apply Regression to Test Set
target_pred_test = log_reg.predict(data_test)

# %%
# Compute the Accuracy of the Training and Test Set
target_pred_train = log_reg.predict(data_train)

accuracy_test = metrics.accuracy_score(target_test, target_pred_test)
accuracy_train = metrics.accuracy_score(target_train, target_pred_train)

print("Accuracy of Test Data:", accuracy_test)
print("Accuracy of Training Data:",accuracy_train)
# Out:
# Accuracy of Test Data: 0.9129283771532185
# Accuracy of Training Data: 0.9128353445696619

# %%
# Create confusion matrix
_ = metrics.ConfusionMatrixDisplay.from_estimator(log_reg, data_test, target_test, normalize = 'true')

# %%
# Apply Regression to Entire Dataset
df2_ = pd.DataFrame(df2_PC)
probs = log_reg.predict_proba(df2_)
probs_df = pd.DataFrame(probs, columns = ["No Upwelling Probability", "Upwelling Probability"])
df_full = pd.concat([df, probs_df], axis = 1)
corr_matrix = df_full.corr()
corr_matrix.style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_761f2_row0_col0, #T_761f2_row1_col1, #T_761f2_row2_col2, #T_761f2_row3_col3, #T_761f2_row4_col4, #T_761f2_row5_col5, #T_761f2_row6_col6, #T_761f2_row7_col7, #T_761f2_row8_col8, #T_761f2_row9_col9, #T_761f2_row10_col10, #T_761f2_row11_col11, #T_761f2_row12_col12, #T_761f2_row13_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_761f2_row0_col1, #T_761f2_row2_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_761f2_row0_col2, #T_761f2_row1_col2, #T_761f2_row6_col10, #T_761f2_row8_col2, #T_761f2_row8_col3, #T_761f2_row11_col5 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_761f2_row0_col3, #T_761f2_row0_col10, #T_761f2_row4_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_761f2_row0_col4, #T_761f2_row3_col11 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_761f2_row0_col5, #T_761f2_row7_col4, #T_761f2_row13_col9 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_761f2_row0_col6, #T_761f2_row12_col3, #T_761f2_row13_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_761f2_row0_col7, #T_761f2_row2_col7, #T_761f2_row7_col9 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_761f2_row0_col8, #T_761f2_row2_col8 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_761f2_row0_col9, #T_761f2_row9_col5 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_761f2_row0_col11, #T_761f2_row2_col10 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_761f2_row0_col12 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_761f2_row0_col13, #T_761f2_row7_col10 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_761f2_row1_col0, #T_761f2_row2_col0, #T_761f2_row6_col1, #T_761f2_row8_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_761f2_row1_col3, #T_761f2_row4_col3, #T_761f2_row8_col6 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T
{
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_761f2_row11_col1

# %% [markdown]
# # Non-spatial

# %%
# Load Dataset, Apply PCA and Create PCs

# Create DataFrame
df1 = pd.read_csv('upwelling_nonspatial.csv')
df1 = df1.drop(columns = ['date (string)'])
df1 = df1.dropna()

# Normalise the DataFrame
df3 = df1.drop(columns=['upwelling3day','upwelling1day'], axis = 1)

df3_mean = df3.mean()
df3_stdev = df3.std()
df3_norm = (df3 - df3_mean) / df3_stdev

target1 = df1['upwelling3day']

# %%
# Apply PCA
pca = PCA(n_components = 8)
df4_PC = pca.fit_transform(df3_norm)

# Number of Upwelling Events and No Upwelling Events
upwelling_ = df1['upwelling3day']
Upwelling1_ = np.sum(upwelling == 1)
Upwelling0_ = np.sum(upwelling == 0)

print('There are', Upwelling1_, 'instances of Upwelling')
print('There are', Upwelling0_, 'instances of No Upwelling')
# Out:
# There are 11513 instances of Upwelling
# There are 126359 instances of No Upwelling

# %%
# Create Training and Test Sets  
data_train1, data_test1, target_train1, target_test1 = train_test_split(df4_PC, target1, test_size = 0.20, random_state = 0, shuffle = True)

# %%
# Performing a Logistic Regression on a Training Set
log_reg1 = LogisticRegression()
log_reg1.fit(data_train1, target_train1)
# Out:
# LogisticRegression()

# %%
# Apply Regression to Test Set
target_pred_test1 = log_reg1.predict(data_test1)

# %%
# Compute the Accuracy of the Training and Test Set
target_pred_train1 = log_reg1.predict(data_train1)

accuracy_test1 = metrics.accuracy_score(target_test1, target_pred_test1)
accuracy_train1 = metrics.accuracy_score(target_train1, target_pred_train1)

print("Accuracy of Test Data:", accuracy_test1)
print("Accuracy of Training Data:",accuracy_train1)
# Out:
# Accuracy of Test Data: 0.8623481781376519
# Accuracy of Training Data: 0.8865248226950354

# %%
# Create confusion matric
__ = metrics.ConfusionMatrixDisplay.from_estimator(log_reg1, data_test1, target_test1, normalize = 'true')

# %%
# Apply Regression to Entire Dataset
df4_ = pd.DataFrame(df4_PC)
probs1 = log_reg1.predict_proba(df2_)
probs_df1 = pd.DataFrame(probs, columns = ["No Upwelling Probability", "Upwelling Probability"])
df_full1 = pd.concat([df1, probs_df1], axis = 1)
corr_matrix1 = df_full1.corr()
corr_matrix1.style.background_gradient(cmap = 'Blues')
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/formats/style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /opt/anaconda3/lib/python3.12/site-packages/pandas/io/formats/style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_689dc_row0_col0, #T_689dc_row3_col3, #T_689dc_row4_col4, #T_689dc_row5_col5, #T_689dc_row6_col6, #T_689dc_row7_col7, #T_689dc_row8_col8, #T_689dc_row9_col9, #T_689dc_row10_col10, #T_689dc_row11_col11, #T_689dc_row12_col12, #T_689dc_row13_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_689dc_row0_col1, #T_689dc_row0_col2, #T_689dc_row1_col0, #T_689dc_row1_col1, #T_689dc_row1_col2, #T_689dc_row1_col3, #T_689dc_row1_col4, #T_689dc_row1_col5, #T_689dc_row1_col6, #T_689dc_row1_col7, #T_689dc_row1_col8, #T_689dc_row1_col9, #T_689dc_row1_col10, #T_689dc_row1_col11, #T_689dc_row1_col12, #T_689dc_row1_col13, #T_689dc_row2_col0, #T_689dc_row2_col1, #T_689dc_row2_col2, #T_689dc_row2_col3, #T_689dc_row2_col4, #T_689dc_row2_col5, #T_689dc_row2_col6, #T_689dc_row2_col7, #T_689dc_row2_col8, #T_689dc_row2_col9, #T_689dc_row2_col10, #T_689dc_row2_col11, #T_689dc_row2_col12, #T_689dc_row2_col13, #T_689dc_row3_col1, #T_689dc_row3_col2, #T_689dc_row4_col1, #T_689dc_row4_col2, #T_689dc_row5_col1, #T_689dc_row5_col2, #T_689dc_row6_col1, #T_689dc_row6_col2, #T_689dc_row7_col1, #T_689dc_row7_col2, #T_689dc_row8_col1, #T_689dc_row8_col2, #T_689dc_row9_col1, #T_689dc_row9_col2, #T_689dc_row10_col1, #T_689dc_row10_col2, #T_689dc_row11_col1, #T_689dc_row11_col2, #T_689dc_row12_col1, #T_689dc_row12_col2, #T_689dc_row13_col1, #T_689dc_row13_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_689dc_row0_col3, #T_689dc_row6_col3, #T_689dc_row11_col0 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_689dc_row0_col4, #T_689dc_row0_col10 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_689dc_row0_col5, #T_689dc_row6_col4 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_689dc_row0_col6 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_689dc_row0_col7, #T_689dc_row12_col10 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_689dc_row0_col8, #T_689dc_row13_col10 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_689dc_row0_col9 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_689dc_row0_col11, #T_689dc_row8_col4 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_689dc_row0_col12, #T_689dc_row3_col9, #T_689dc_row4_col9, #T_689dc_row4_col11, #T_689dc_row11_col12 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_689dc_row0_col13, #T_689dc_row11_col13 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_689dc_row3_col0, #T_689dc_row4_col6, #T_689dc_row8_col3 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_689dc_row3_col4 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_689dc_row3_col5 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_689dc_row3_col6 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_689dc_row3_col7 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_689dc_row3_col8, #T_689dc_row6_col9 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_689dc_row3_col10 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_689dc_row3_col11 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_689dc_row3_col12, #T_689dc_row6_col12 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_689dc_row3_col13, #T_689dc_row6_col13 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_689dc_row4_col0, #T_689dc_row8_col6 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_689dc_row4_col3, #T_689dc_row10_col8, #T_689dc_row11_col3, #T_689dc_row12_col6 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_689dc_row4_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_689dc_row4_col7 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_689dc_row4_col8 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_689dc_row4_col10, #T_689dc_row10_col7 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_689dc_row4_col12, #T_689dc_row5_col8, #T_689dc_row13_col9 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_689dc_row4_col13 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_689dc_row5_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_689dc_row5_col3, #T_689dc_row5_col4, #T_689dc_row5_col7, #T_689dc_row5_col10, #T_689dc_row5_col11, #T_689dc_row7_col6, #T_689dc_row8_col9, #T_689dc_row9_col8, #T_689dc_row10_col5, #T_689dc_row12_col0, #T_689dc_row12_col13, #T_689dc_row13_col12 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_689dc_row5_col6, #T_689dc_row7_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_689dc_row5_col9, #T_689dc_row13_col8 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_689dc_row5_col12, #T_689dc_row7_col4, #T_689dc_row9_col11 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_689dc_row5_col13 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_689dc_row6_col0, #T_689dc_row13_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_689dc_row6_col5 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_689dc_row6_col7, #T_689dc_row12_col11 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_689dc_row6_col8 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_689dc_row6_col10 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_689dc_row6_col11 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_689dc_row7_col3, #T_689dc_row10_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_689dc_row7_col5, #T_689dc_row8_col0, #T_689dc_row13_col3, #T_689dc_row13_col6 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_689dc_row7_col8 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_689dc_row7_col9, #T_689dc_row11_col7 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_689dc_row7_col10 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_689dc_row7_col11, #T_689dc_row12_col8 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_689dc_row7_col12 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_689dc_row7_col13 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_689dc_row8_col5 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_689dc_row8_col7, #T_689dc_row12_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_689dc_row8_col10 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_689dc_row8_col11 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_689dc_row8_col12 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_689dc_row8_col13 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_689dc_row9_col0 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_689dc_row9_col3, #T_689dc_row12_col7 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_689dc_row9_col4 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_689dc_row9_col5 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_689dc_row9_col6 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_689dc_row9_col7 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_689dc_row9_col10 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_689dc_row9_col12 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_689dc_row9_col13 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_689dc_row10_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_689dc_row10_col4 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_689dc_row10_col6 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_689dc_row10_col9 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_689dc_row10_col11 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_689dc_row10_col12 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_689dc_row10_col13 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_689dc_row11_col4 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_689dc_row11_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_689dc_row11_col6 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_689dc_row11_col8 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_689dc_row11_col9 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_689dc_row11_col10 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_689dc_row12_col4 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_689dc_row12_col5 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_689dc_row12_col9 {
#   background-color: #a6cee4;
